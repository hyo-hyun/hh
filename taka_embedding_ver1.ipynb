# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.chdir(r'C:\Users\itwill\Desktop')
print(os.getcwd())
# Out:
# C:\Users\itwill\Desktop

# %%
import pandas as pd
data_taka=pd.read_csv('taka_remove.csv')

# %%
import re
import emoji

def clean_text(text):
    # 이모지 제거
    text = emoji.replace_emoji(text, replace='')

    # 줄바꿈 → 공백
    text = re.sub(r'\n', ' ', text)

    # 숫자 포함
    text = re.sub(r'\S*\d\S*', '', text)

    # 한자 제거
    text = re.sub(r'#\S*[\u4E00-\u9FFF]\S*', '', text)

    # 일본어 거거
    text = re.sub(r'#\S*[\u3040-\u309F\u30A0-\u30FF]\S*', '', text)

    # 한자/일본어 제거
    text = re.sub(r'[\u4E00-\u9FFF\u3040-\u309F\u30A0-\u30FF]', '', text)

    # 특수문자 제거 
    text = re.sub(r'[^\w\s#]', '', text)

    # 여러 공백을 하나로, 양쪽 공백 제거
    text = re.sub(r'\s+', ' ', text).strip()

    return text


data_taka['caption_clean'] = data_taka['caption'].apply(lambda x: clean_text(x) if isinstance(x, str) else '')

# %%
data_taka.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            246 non-null    object
#  1   caption        246 non-null    object
#  2   hashtags       213 non-null    object
#  3   likes          240 non-null    float64
#  4   image_url      246 non-null    object
#  5   caption_clean  246 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 11.7+ KB

# %%
import pandas as pd
data_tongyeong=pd.read_csv('tongyeong.csv')

# %%
import re
import emoji

def clean_text(text):
    # 이모지 제거
    text = emoji.replace_emoji(text, replace='')

    # 줄바꿈 → 공백
    text = re.sub(r'\n', ' ', text)

    # 숫자 포함
    text = re.sub(r'\S*\d\S*', '', text)

    # 한자 제거
    text = re.sub(r'#\S*[\u4E00-\u9FFF]\S*', '', text)

    # 일본어 거거
    text = re.sub(r'#\S*[\u3040-\u309F\u30A0-\u30FF]\S*', '', text)

    # 한자/일본어 제거
    text = re.sub(r'[\u4E00-\u9FFF\u3040-\u309F\u30A0-\u30FF]', '', text)

    # 특수문자 제거 
    text = re.sub(r'[^\w\s#]', '', text)

    # 여러 공백을 하나로, 양쪽 공백 제거
    text = re.sub(r'\s+', ' ', text).strip()

    return text


data_tongyeong['caption_clean'] = data_tongyeong['caption'].apply(lambda x: clean_text(x) if isinstance(x, str) else '')

# %%
###################################################    KoBERT     #####################################################

# %%
from kobert_transformers import get_tokenizer
from transformers import BertModel

model = BertModel.from_pretrained("monologg/kobert")
tokenizer = get_tokenizer()

# 문장
sentence = "안녕하세요, KoBERT 테스트 중입니다."

# 4. 토큰화 출력
tokens = tokenizer.tokenize(sentence)
print("Tokens:", tokens)

# 5. 토큰을 모델 입력 형태로 변환
inputs = tokenizer(sentence, return_tensors="pt")

# 6. 모델에 입력 후 출력 받기
outputs = model(**inputs)

print("Last Hidden State shape:", outputs.last_hidden_state.shape)
print("Pooler Output shape:", outputs.pooler_output.shape)
# Out:
# Tokens: ['▁안', '녕', '하세요', ',', '▁K', 'o', 'B', 'ER', 'T', '▁테스트', '▁중', '입니다', '.']
# Last Hidden State shape: torch.Size([1, 15, 768])
# Pooler Output shape: torch.Size([1, 768])

# %%
import transformers
import kobert_transformers
print(transformers.__version__)  # 4.54.1 이상이면 충분함
print(kobert_transformers.__version__)  # 0.6.0 이상이면 충분함
# Out:
# 4.54.1
# 0.6.0

# %%
import kobert_transformers
print(dir(kobert_transformers))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'f', 'get_distilkobert_lm', 'get_distilkobert_model', 'get_kobert_lm', 'get_kobert_model', 'get_tokenizer', 'load_model', 'os', 'tokenization_kobert', 'utils', 'version_txt']

# %%
from kobert_transformers import get_tokenizer
from transformers import BertModel

model = BertModel.from_pretrained("skt/kobert-base-v1")
tokenizer = get_tokenizer()

# 문장
sentence = "안녕하세요, KoBERT 테스트 중입니다."

# 4. 토큰화 출력
tokens = tokenizer.tokenize(sentence)
print("Tokens:", tokens)

# 5. 토큰을 모델 입력 형태로 변환
inputs = tokenizer(sentence, return_tensors="pt")

# 6. 모델에 입력 후 출력 받기
outputs = model(**inputs)

print("Last Hidden State shape:", outputs.last_hidden_state.shape)
print("Pooler Output shape:", outputs.pooler_output.shape)

# last_hidden_state : 문장 내 각 토큰의 문맥적 의미 임베딩
# pooler_output : 문장 전체를 대표하는 임베딩 벡터, [cLS]토큰의 마지막 hidden state에 tanh활성화 함수를 적용한 값
# Out:
# Tokens: ['▁안', '녕', '하세요', ',', '▁K', 'o', 'B', 'ER', 'T', '▁테스트', '▁중', '입니다', '.']
# Last Hidden State shape: torch.Size([1, 15, 768])
# Pooler Output shape: torch.Size([1, 768])

# %%
############kobert 사용해서 토큰화가 어떻게 수행되었는지 보기

# %%
tokenized_texts = [tokenizer.tokenize(sentence) for sentence in data_taka['caption_clean']]
data_taka["tokens"] = data_taka['caption_clean'].apply(lambda x: tokenizer.tokenize(x))
data_taka.to_csv("taka_tokenized_check_and_remove.csv", index=False, encoding="utf-8-sig")

data_taka.drop(columns=["tokens"], inplace=True)

# %%
##############       kobert 예시       ##############

import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity

# KoBERT 모델과 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertModel.from_pretrained('bert-base-multilingual-cased')

# 문장을 임베딩으로 변환하는 함수
def get_embedding(text):
    # 텍스트를 토큰화
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    
    # 모델을 통해 임베딩 계산
    with torch.no_grad():
        outputs = model(**inputs)
    
    # 임베딩은 마지막 hidden state를 사용
    embeddings = outputs.last_hidden_state.mean(dim=1)  # 평균으로 문서 임베딩을 구함
    
    return embeddings

# 두 문서 예시
doc1 = "오늘 날씨가 너무 좋다."
doc2 = "오늘은 날씨가 맑고 기분이 좋다."

# 각 문서의 임베딩을 구함
embedding1 = get_embedding(doc1)
embedding2 = get_embedding(doc2)

# 코사인 유사도 계산
cos_sim = cosine_similarity(embedding1.numpy(), embedding2.numpy())
print(f"Cosine similarity between the two documents: {cos_sim[0][0]}")
# Out:
# Cosine similarity between the two documents: 0.7597843408584595

# %%
#글이 길면 토큰이 잘릴 수 있으므로 문장 요약을 하거나, 
#글의 길이나 좋아요 수 등을 고려하여 각 글에 가중치를 부여할 수 도 있다.
#250개의 글에 대해 한 번에 bert임베딩을 하면 메모리 사용량이 너무 많을 수 있으니 이때는 배치(batch)처리로 나누어서 임베딩 구할 수 있음

# %%
from kobert_transformers import get_tokenizer
from transformers import BertModel

model = BertModel.from_pretrained("skt/kobert-base-v1")
tokenizer = get_tokenizer()

def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)

    #메모리 효율을 위해 with구문 사용함
    with torch.no_grad():
        outputs = model(**inputs)
    
    #평균 풀링: 모든 토큰의 표현에 평균 풀링으로 문장 표현을 얻으면 문장 표현은 본질적으로 모든 단어(토큰)의 의미를 가짐
    embeddings = outputs.last_hidden_state.mean(dim=1)
    
    return embeddings
    
def add_embeddings_to_dataframe(data_taka):
    embeddings = []
    for text in data_taka['caption_clean']:
        emb = get_embedding(text)
        embeddings.append(emb.squeeze().numpy())  # 텐서를 numpy 배열로 변환 후 리스트에 추가
    
    # 새 컬럼 'embedding'으로 임베딩 값 추가
    data_taka['embeddings'] = embeddings
    return data_taka

# DataFrame에 임베딩 추가
data_with_embeddings = add_embeddings_to_dataframe(data_taka)

# 결과 출력
print(data_taka['embeddings'][:5])
# Out:
# 0    [0.015660496, -0.12379188, 0.29436022, -3.8897...
# 1    [-0.023761913, -0.121277794, 0.40451685, -5.30...
# 2    [0.004951356, -0.09263014, 0.20708022, -3.7605...
# 3    [-0.065095134, -0.218861, 0.075367354, -3.2439...
# 4    [0.09418768, -0.18728587, 0.19061619, -3.62158...
# Name: embeddings, dtype: object

# %%
from kobert_transformers import get_tokenizer
from transformers import BertModel

model = BertModel.from_pretrained("skt/kobert-base-v1")
tokenizer = get_tokenizer()

def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    #평균 풀링: 모든 토큰의 표현에 평균 풀링으로 문장 표현을 얻으면 문장 표현은 본질적으로 모든 단어(토큰)의 의미를 가짐
    embeddings = outputs.last_hidden_state.mean(dim=1)
    
    return embeddings

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 이미지 경로 설정
img = mpimg.imread(r'C:\Users\itwill\Desktop\okt.png')

# 이미지를 화면에 표시
plt.figure(dpi=300)
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
from konlpy.tag import Okt
okt=Okt()
def extract_nouns(text):
    # Okt를 사용해 명사만 추출
    nouns = okt.nouns(text)
    # 한 단어로 이루어진 명사는 삭제
    filtered_nouns = [noun for noun in nouns if len(noun) > 1]
    return ' '.join(filtered_nouns)


data_taka['caption_nouns'] = data_taka['caption_clean'].apply(extract_nouns)
result_taka = ' '.join(data_taka['caption_nouns'])

data_tongyeong['caption_nouns'] = data_tongyeong['caption_clean'].apply(extract_nouns)
result_tongyeong= ' '.join(data_tongyeong['caption_nouns'])

# %%
print(result_taka)
# Out:
# 디토 지금 일본 다카마쓰 여행 도시 행복 저장 공유 필수 다카마쓰 인생 우동 그릇 뚝딱 가면 무조건 맛집 힐링 관광 스팟 정리 이제 뱅기 티켓 숙소 예약 바로 다카마쓰 준비 완료 매장 주소 댓글 확인 일본 다카마쓰 우동 투어 나미 당일치기 우동 투어 하시모토 면소 젓가락 그릇 필요 기대 아빠 그냥 생각 나무 젓가락 거기 몇개 간장 아주 조금 비비고 넣기 마쓰 치킨 카레 우동 카시 덴푸라 가루 고추기름 비비 진짜 아빠 먹음 나미 보고 주문 잘못 카시 튀김 세이 우동 레스토랑 우동 우동 소스 생강 넣기 얼음 만큼 우동 와사비 추천 우동 생강 한국말 외국인 직원 소통 튀김 가루 식감 튀김 가루 모리 우동 튀김 우동 미니 기사 추천 모리 우동 분위기 삼삼오오 사람 체인점 미니 우동 요기 간다 추천 미니 여성 튀김 바싹 국물 조금 자극 공항 진짜 여기 강추 셀프 우동 노부 마감 미리 미리 택시 합의 보시 나미 공항 미리 협의 추천 가격 거나 고정 회사 연락 이야기 기사 얼마나 전혀 문제 시간 처음 택시 정도 타고 택시 정도 계산 당일치기 시간 싸움 시간 협의 정말 택시 보이지 잡기 가게 택시 불러쥬셔 바로 가게 택시 달라 동선 조금 가뜩이나 직원 실례 기사 지름길 가시 역시 택시 폭탄 각오 일본 다카마쓰 붓쇼잔 온천 노천 실내 냉탕 구분 샴푸 바디 워시 용품 비치 비누 로션 중고 서적 판매 내부 식당 힐링 시간 사진 부채 붓쇼잔 패스 다카마쓰 칫코역 역무 구매 당일 기준 다카마쓰 칫코역 붓쇼잔역 무제한 탑승 온천 입장료 포함 구매 토토 야돈 우동 고토덴 버스 다카마쓰 여행 처음 단둘 여행 컨디션 별로 불구 순간 여행 무엇 계단 절대 예전 여행 마음 일본 소도시 여행 세토대교 고토 공원 이야기 블로그 보물섬 투어 다카 마츠 자연 힐링 우동 예술 다카 마츠 여행 패키지 오이 토핑 소프트 아이스크림 제공 일본 전통 온천 보물섬 투어 힐링 다카 마츠 여행 내용 홈페이지 확인 다카마쓰 우동 당일치기 최소 이유 강남 다카마쓰 우동 당일치기 우동 정보 쌈뽕 당일치기 가능 진에어 일리 항공 편이 오후 시간 조정 오전 에어 서울 오후 진에어 당일치기 생각 직접 실현 이상 이유 경험 우동 생각 다카마쓰 이번 콘텐츠 우동 집중 소개 우동 기준 우동 종류 가케 우동 가마 타마 우동 자루 우동 붓카케 우동 우동 선택 재미 가게 스타일 셀프 조리 정통 레스토랑 면소 올해 최소 이상 우동 투어 운영 예정 카가와현 우동 무려 이상 우동 투어 입장 콘텐츠 군데 추천 카가와현 우동 맛집 리스트 야마 우동 가마 타마 계란 우동 원조 가게 야마시타 우동 붓카케 우동 원조 히야아츠히야아츠 선택 가능 자키 식료품점 식료품점 우동 명소 메뉴 가타 우동 쇼유 우동 원조 직접 재미 히노 면소 영업 시간 카가와 가장 면발 최상급 가타 카노 가마 우동 최강 가모 우동 츠루 마루 다카마쓰 카레 우동 성지 야간 영업 고에몬 근처 위치 카레 쿠로 카레 우동 명소 우동 가마 버터 우동 영업 시간 접근성 마쓰시타 면소 가케우동 매력 야마다 정원 우동 상견례 장소 가능 와후쿠 자루 우동 원조 가게 치쿠 세이 치쿠 어묵 튀김 우동 조합 예술 사누키 라멘 하만 우동 라멘 코로나 이전 곱창 우동 우동 샤브샤브 우동 메뉴 지금 카가와현 우동 맛집 추천 우동 우동 지도 링크 모리 우동 스토리 에어 서울 다카마쓰 취항 방문 왕복 프로모션 덕분 시작 인연 우동 일본정부 관광 재팬 홍보 캠페인 진행 일치 덕업 일치 우동 투어 운영 진짜 우동 올해 세토우치 예술제 진행 콘텐츠 만큼 우동 생각 일본 시코쿠 다카 마츠시 다카 마츠역앞 우동 메리 카이 우마 하마 카이 마치 해산물 전문 이자카야 종류 초밥 참치 덕분 둘이서 일본 공원 기린 나마 비루 맥주 한잔 힐링 이제 다다다 다다다 상점가 다카마쓰 저녁 하나 마루 우동 해결 도시마 엔젤 로드 다음 스케쥴 취소 다카마쓰 여행 다카마쓰 구라시키 구라시키 반나절 투어 다카마쓰 여행 근처 갈수 도시 푸릇푸릇 미관 지구 소도시 투어 낭만 충족 상점 경도 에드 카페 발견 커피 홀짝 다가 사진 한번 사진 별거 별거 기선 전반 음식 마음 포인트 오코노미야키 이면 우동 나마 비루 마무리 우동 다카마쓰 닭다리 구이 나마 비루 마무리 시킴 엉덩이 박살 다카마쓰 여행 단돈 우동 야돈 여행 일본 다카마쓰 코스 완전 정복 한국인 시골 감성 힐링 페리 타고 도시마 탐방 도쿄 오사카 이번 진짜 일본 로컬 다카마쓰 다카마쓰 코스 다카마쓰 도착 패스 구매 다카마쓰 지하철역 근처 지하철 티켓 온천 입장권 포함 패스 구매 붓쇼잔 온천 도심 지하철 거리 소도시 감성 노천 단토 라멘 기숙 육수 로컬 맛집 도시마 도착 야돈 페리 탑승 올리브 공원 키키 빗자루 무료 대여 가능 인생 예약 올리브 소프트아이스크림 진짜 올리브 맛남 오오 미네 우동 가게 쫄깃 면발 직접 우동 모습 눈앞 헬로 사이클링 자전거 투어 자전거 전혀 마을 풍경 구경 엔젤 로드 하루 길이 로맨틱 장소 연인 끼리 소원 전설 다카마쓰 귀환 야돈 페리 탑승 다카마쓰 이온 하마 스시 가성 최고 회전초밥 맛집 거의 모든 접시 토리 일본 여행 마무리 역시 야키토리 생맥주 공원 일본 정원 하나 연못 돌다리 정자 그림 가득 마루 마치 상점가 일본 감성 쇼핑 거리 도시락 먹방 마트 마트 초밥 도시락 다카마쓰 공항 출국 우동 그릇 공항 우동 자동 자판기 체험 가능 다카마쓰 경비 정리 기준 대략 가성 비용 항공권 진에어 다카마쓰 직항 왕복 숙소 기준 가격 에어비앤비 교통비 버스 지하철 페리 헬로 사이클링 포함 식비 우동 라멘 초밥 야키토리 쇼핑 식사 가능 우동 스시 식사 식비 세이브 에어비앤비 숙소 세이브 내용 공감 언제 다시 보고 저장 주변 사람 공유 매일 여행 꿀팁 보고 팔로우 사진 영상 제공 모든 친구 여행 각자 시간 내기 이제 한숨 모든 기념 여행 각자 여행 진짜 전날 조마조마 우여곡절 결론 힐링 여행 각자 일본 다카 마츠 마로 결정 일본 변방 여유 마는 하나 전체 박물관 정도 여러 박물관 자연 경관 종교 경험 안도 다다 건축물 작품 빛과 건축 예술 합의 경지 영혼 울림 전혀 사전 지식 박물관 거의 충격 감동 지엄 작품 호텔 작품 주위 경관 박물관 박물관 셔틀 우리 최대한 자연 하루 종일 해안가 호박 바다 배경 하니 존재 폐가 개조 이에프 프로젝트 우리 현실 일정 어디 인지 인지 곳곳 기대 이상 즐거움 감동 십년 친구 서로 이기 때문 여행 스켈줄 삐걱 거림 시간 선물 다카 마츠 시골 동네 적함 안정감 곳곳 우리 리쯔린 공원 일본 정원 정수 이승 저승 경계 어디 생각 요즘 일본 가면 물반 한국 사람 던데 우리 여행 이제 시작 어디 경비 일본 여행 항공권 숙박 음료 쇼핑 뿌신 우리 우정 여행 행복감 비용 비례 다카마쓰 우동 시기 우동 우동 고장 자전거 타고 동네 바퀴 공용 자전거 자전거 도로 도시 자전거 꿀잼 일본 공원 공원 공원 카페 다도 체험 근거리 온천 붓쇼잔 온천 포카포카 온천 유명 다카마쓰 시내 버스 거리 동네 러닝 인도 사람 도시 시티 하라 동네 항공권 에어 서울 왕복 숙소 호스텔 기준 식비 기준 끼니 우동 저렴 쇼핑 돈키호테 하나 오차즈케 자전거 대여 기타 교통비 버스 전철 이용 차비 인천공항 장기 주차 다카마쓰 일본 예약 시간 구경 한창 상태 시간 얼마나 보고 가격 아주 가야 생각 가야 야시 수족관 통과 도사 도시 바다 전망 진심 최고 한국 다카마쓰 만난 일본인 친구 친구 지금 한국 가마 버터 처음 시작 게살 크림 고로케 장소 사진 부탁 폭격기 니뽄 분위기 마챠 쿠다사잇 쿠게츠 테이 공원 위치 말차 공원 입장료 다카마쓰 다카마쓰 여행 우동 도시 온통 우동 다카마쓰 공원 다카마쓰 보배 우동 덴뿌라 우동 정말 인생 우동 후르 산도 메론 마지막 아침 크로크마담 별루 우동 다카마쓰 기념품 천국 다카마쓰 여행 가면 무조건 쇼핑 리스트 공유 감성 쇼핑 여행 마무리 팔로우 여행 꿀팁 정보 해외 다카마쓰 파노라마 한눈 다카마쓰 바로 세토나이카이 눈앞 매력 전망대 언제 방문 무료 스팟 혼자 낭만 다카마쓰 여행 우동 고장 우동 천국 다카마쓰 혼키돈쿠 구글 연속 우동 이건 선택 샐러드 드레싱 돈까스 소스 정식 국도 톤지루 제대로 레몬 계속 생각 우동 구글 우동 버터 조각 계란 쇼유 소스 뿌리 통후추 나름 소스 튀김 그것 츠키 도리 마루 구글 다카마쓰 메인  ...

# %%
len(set(result_taka.split()))
# Out:
# 2406

# %%
len(set(result_tongyeong.split()))
# Out:
# 3022

# %%
top_taka = [word for word, _ in counter_taka.most_common(500)]
top_tongyeong = [word for word, _ in counter_tongyeong.most_common(500)]


taka = ' '.join(top_taka)
tongyeong= ' '.join(top_tongyeong)


print(taka)
print('##########################')
print(tongyeong)
# Out:
# 우동 다카마쓰 여행 일본 공원 시간 다카 소도시 야돈 사진 마츠 투어 예약 시코쿠 호텔 추천 예술 도시 미술관 맛집 온천 진짜 하나 숙소 버스 방문 생각 튀김 카페 사람 정말 가장 마루 도시마 공항 이번 정원 하루 힐링 카가와현 마치 자전거 작품 우리 바로 여기 가게 포함 사누키 올리브 다시 타고 역시 가능 감성 도착 쇼핑 호박 지역 정도 고토 자연 페리 최고 바다 일정 고장 슬라이드 그냥 보고 국물 패스 입장료 정보 이상 시작 항공권 아침 혼자 순례 카레 전통 가마 위치 매력 왕복 다음 코스 한국 아트 필수 그릇 분위기 처음 서울 타마 메뉴 링크 음식 거리 무료 가득 리츠 모두 오늘 다카마츠 시마 인생 면소 택시 가격 아이스크림 에어 운영 카가와 라멘 이자카야 친구 어디 전망대 사실 바람 편의점 카마 오픈 가가와현 무조건 관광 마음 영업 근처 가성 때문 이용 느낌 비행기 오뎅 먹기 명물 지금 조금 모리 내부 오후 경험 면발 버터 저녁 풍경 여유 동네 시내 기념품 츠키 계획 일본여행 신사 료칸 산책 후쿠오카 프렌즈 이제 당일치기 주문 미리 기준 계단 이유 직접 소개 선택 재미 장소 한잔 마무리 키키 모든 연못 체험 팔로우 박물관 안도 지엄 배경 계속 도리 이름 추억 오카야마 우치 국제 날씨 조식 설계 대표 찻집 거북이 정리 구매 내용 원조 진행 예술제 하마 한번 영상 경관 프로젝트 숙박 산도 출발 여행지 기분 개인 사찰 세계 공간 사누끼 저장 가면 댓글 확인 기대 아주 직원 보시 붓쇼잔 별로 오이 진에어 오전 콘텐츠 종류 야마 성지 덕분 세토우치 상점가 엔젤 로드 구라시키 낭만 커피 시골 길이 기념 건축 감동 존재 만난 마지막 기차 인천 내내 곤피 사랑 세상 체크 전시 프로필 여름 정육점 이우환 건물 최대 가이드 하늘 호수 마녀 배달 후기 교자 중간 역사 이동 라운지 먼저 제일 기억 도미 갤러리 스팟 준비 아빠 거기 소스 무제한 탑승 순간 무엇 항공 집중 올해 명소 츠루 미관 지구 발견 닭다리 한국인 대여 구경 토리 경비 식사 주변 마는 건축물 종일 곳곳 음료 돈키호테 가야 야시 일본인 테이 구글 나름 감탄 다른 바삭 근교 운항 소요 점심 다리 만날 시대 그대로 두번째 휴무 구석구석 모토 잠시 새벽 어제 감상 미슐랭 규모 문의 뱃놀이 이자 사마 미식 연어 본점 현지 엄마 요리 레일 디저트 수도꼭지 볼거리 스타 그램 공부 참고 자리 자체 과일 사케 포토 맨홀 속닥 뱅기 나무 간장 세이 식감 간다 전혀 식당 예전 블로그 제공 자루 붓카케 예정 군데 계란 식료품점 어묵 조합 취항 홍보 메리 초밥 나마 비루 별거 도쿄 오사카 로컬 도심 빗자루 모습 마을 거의 야키토리 그림 먹방 비용 직항 교통비 언제 꿀팁 전체 선물 요즘 진심 크림 이건 제대로 웨이팅 하이 과거 동안 다섯 저희 부스러기 학교 과연 기록 편도 포기 그때 우동현 내일 장인 관심 혼무 벚꽃 일상 간조 현대 클릭 돌고래 오션 구성 일단 주목 규슈 혼슈 가세 부가 아래 업로드 관련 상징 찍기 촬영 겨울 보기 아쿠아리움 관람 일차 서비스 애프터눈티 실제 주말 다음주 멀리 피코 피해 지인 검색 일주일 그린 온라인 현금 하우스 인증샷 미술 마츠다 한국어 북적 가요 몽골 귀국 스냅 마스 고치 공유 티켓 나미 젓가락 카시 가루 잘못 레스토랑 생강 만큼 와사비 미니 기사 체인점 요기 셀프 노부 마감
# ##########################
# 통영 여행 통영시 경남 카페 바다 맛집 여름 케이크 추천 시간 거제 디저트 공원 마을 수국 힐링 코스 축제 펜션 고양이 고성 투어 벽화 비진도 행사 마음 사진 이번 한산 풍경 방문 휴가 여행지 욕지도 자연 필수 확인 사람 체험 장소 여유 가능 오션 도시 하나 소개 요트 준비 바로 위치 이순신 아이 매일 하루 감성 해산물 해수욕장 친구 불꽃 대첩 공간 그램 참여 경상남도 예약 신청 음식 시작 기간 여기 스타 식당 빙수 운영 팔로우 분위기 휴무 추억 광도면 정말 영업 참고 이벤트 오늘 진짜 안내 타고 케이블카 산책 산양읍 문의 골목 학교 시장 진행 무료 선상 우리 가장 가족 검색 오후 구안 정원 일상 이용 사량 오전 노을 정보 주문 네이버 여러분 애견 방법 정량동 디피 관광 관광지 유람선 오픈 구가 숙소 모두 욕지면 생각 저장 국내 댓글 당첨 다시 데이트 아이스크림 직접 할인 바람 광장 푸른 용남면 여권 와팡 용호 사랑 개인 일주 투나잇 중앙 전통 매력 주차 로컬 지금 날씨 공연 커피 해양 참가 이야기 메뉴 라면 거리 해상 계속 도산면 태그 일원 계획 낭만 보고 포토 동반 자체 카드 재료 정상 레터 잠시 내용 더위 경험 전복 기분 가게 정도 아침 해안로 구매 주말 봉수 관람 도깨비 모든 개별 해변 입장 위해 제대로 활동 카트 명소 그림 도착 미리 연화 예술 문화 요즘 대형 텐동 처음 버터 크림 마카롱 한국 제공 때문 프로그램 마무리 도산 공유 예정 루지 한번 다음 구이 해도 추가 링크 정리 부대찌개 호텔 전화 만월 수제 일시 김밥 지역 한눈 남해 엄마 꿀빵 죽림 거제도 충무김밥 제일 포장 지원 관심 이유 경품 남망 지인 동안 저녁 미수동 케이 프로필 국물 제작 카카오 채널 위주 역시 전망대 맥주 매장 센터 보기 청소년 대상 감상 최대 규모 더욱 자리 계절 마치 아래 정화 티켓 업체 만날 강추 입구 치즈 선물 소식 홍보 단체 순간 마지막 구경 국수 대한민국 마당 객실 자전거 대여 아르 최고 중앙시장 기준 물회 사장 재미 에메랄드 밤밤 한산도 캠핑 어디 산양 브레이크 타임 소리 기록 햇살 포인트 레이스 부스 반려견 미래 뉴스 기본 패키지 점심 매점 마감 금요일 일요일 하늘 모음 지도 그냥 올여름 기억 스토리 대표 해저터널 가야 주소 생선 느낌 가득 손님 인테리어 라스트 역사 남동 유자 국적 테라스 바베큐 변경 온라인 사용 먹거리 멍게 여름밤 또한 최초 공룡 세계 모집 고민 피로 통해 항구 일몰 유럽 이상 휴식 라떼 야외 레저 클럽 낚시 환급 이제 가면 올해 가성 발견 토요일 가기 공식 반려동물 부산 택시 식사 여객선 터미널 야간 수영 발표 선수 다른 인생 충전 구성 쫄깃 패밀리 뫼골 무엇 산책로 리조트 허그 동물성 요리 일반 보호 승선 당일 페스 캔들 상품 세상 참가자 곳곳 완성 평가 동시 물놀이 일정 선착순 연중 작성 샌드위치 음료 촬영 수요일 남해안 선사 완전 파라 랑스 언제 버스 어회 전시 광도 가리비 아가씨 목요일 입맛 제로 플라스틱 시민 효과 칼국수 교회 스탬프 댕댕 배양 선셋 도로 수영장 디자인 수륙 길이 모습 내일 도의 주민 동물 지도자 게시 부대 훈련 전국 선택 덕분 컨셉 인스타그램 메인 전복죽 종류 간장 해물 냄새 소스 주차장 동화 정기 스티치 풍자 감동 행복 외국 가격 로만 공지 아시 육회 광어 안주 미수 누구 야경 파라솔

# %%
import torch
from kobert_transformers import get_tokenizer
from transformers import BertModel

from sklearn.metrics.pairwise import cosine_similarity

model = BertModel.from_pretrained("skt/kobert-base-v1")
tokenizer = get_tokenizer()

# 텍스트를 BERT에 맞게 토큰화하고, 임베딩을 추출하는 함수
def embed_text(text):
    # 텍스트를 토큰화 (각 단어를 BERT 입력 형식으로 변환)
    inputs = tokenizer.encode(text, return_tensors="pt", max_length=500, truncation=True, padding=True)
    
    # BERT 모델을 사용해 임베딩 추출
    with torch.no_grad():
        outputs = model(inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)  # 문장의 임베딩은 평균값으로 취합
    
    return embeddings

# 텍스트 임베딩
embedding_taka = embed_text(taka)
embedding_tongyeong = embed_text(tongyeong)

# 코사인 유사도 계산
similarity = cosine_similarity(embedding_taka.numpy(), embedding_tongyeong.numpy())

# 결과 출력
print(f"두 텍스트의 유사도: {similarity[0][0]:.4f}")
# Out:
# 두 텍스트의 유사도: 0.9328

# %%
tokens_taka = tokenizer.tokenize(taka)
print(f"다카마쓰 텍스트 토큰화 결과: {tokens_taka}")
print(f"토큰 개수: {len(tokens_taka)}")
print('###############################')
tokens_tongyeong = tokenizer.tokenize(tongyeong)
print(f"통영 텍스트 토큰화 결과: {tokens_tongyeong}")
print(f"토큰 개수: {len(tokens_tongyeong)}")
# Out:
# 다카마쓰 텍스트 토큰화 결과: ['▁우', '동', '▁다', '카', '마', '쓰', '▁여행', '▁일본', '▁', '공원', '▁시간', '▁다', '카', '▁소', '도시', '▁야', '돈', '▁사진', '▁마', '츠', '▁투어', '▁예약', '▁시', '코', '쿠', '▁호텔', '▁추천', '▁예술', '▁도시', '▁', '미술관', '▁맛', '집', '▁온', '천', '▁진짜', '▁하나', '▁숙', '소', '▁버스', '▁방문', '▁생각', '▁', '튀', '김', '▁카페', '▁사람', '▁정말', '▁가장', '▁마', '루', '▁도시', '마', '▁공항', '▁이번', '▁정', '원', '▁하루', '▁', '힐', '링', '▁카', '가', '와', '현', '▁마치', '▁자전거', '▁작품', '▁우리', '▁바로', '▁여기', '▁', '가', '게', '▁포함', '▁사', '누', '키', '▁올리', '브', '▁다시', '▁타고', '▁역시', '▁가능', '▁감성', '▁도착', '▁쇼핑', '▁호', '박', '▁지역', '▁정도', '▁고', '토', '▁자연', '▁페', '리', '▁최고', '▁바다', '▁일정', '▁고', '장', '▁슬', '라이', '드', '▁그냥', '▁보고', '▁국', '물', '▁패스', '▁입장', '료', '▁정보', '▁이상', '▁시작', '▁항공', '권', '▁아침', '▁혼자', '▁순', '례', '▁카', '레', '▁전통', '▁', '가', '마', '▁위치', '▁매력', '▁왕', '복', '▁다음', '▁코스', '▁한국', '▁', '아트', '▁필수', '▁그', '릇', '▁분위기', '▁처음', '▁서울', '▁타', '마', '▁메뉴', '▁', '링크', '▁음식', '▁거리', '▁무료', '▁가득', '▁리', '츠', '▁모두', '▁오늘', '▁다', '카', '마', '츠', '▁시', '마', '▁인생', '▁면', '소', '▁택시', '▁가격', '▁아이', '스크', '림', '▁', '에', '어', '▁운영', '▁카', '가', '와', '▁라', '멘', '▁이', '자', '카', '야', '▁친구', '▁어디', '▁전망', '대', '▁사실', '▁바람', '▁편의점', '▁카', '마', '▁오픈', '▁', '가', '가', '와', '현', '▁무조건', '▁관광', '▁마음', '▁영업', '▁근처', '▁', '가', '성', '▁때문', '▁이용', '▁느낌', '▁비행기', '▁오', '뎅', '▁먹', '기', '▁명', '물', '▁지금', '▁조금', '▁모', '리', '▁내부', '▁오후', '▁경험', '▁면', '발', '▁버', '터', '▁저녁', '▁풍', '경', '▁여유', '▁동', '네', '▁시', '내', '▁기념', '품', '▁', '츠', '키', '▁계획', '▁일본', '여행', '▁신', '사', '▁', '료', '칸', '▁산', '책', '▁후', '쿠', '오', '카', '▁', '프', '렌', '즈', '▁이제', '▁당', '일', '치', '기', '▁주문', '▁미리', '▁기준', '▁계', '단', '▁이유', '▁직접', '▁소개', '▁선택', '▁재미', '▁장소', '▁한', '잔', '▁마무리', '▁키', '키', '▁모든', '▁연', '못', '▁체험', '▁팔', '로', '우', '▁', '박물관', '▁안', '도', '▁지', '엄', '▁배경', '▁계속', '▁', '도', '리', '▁이름', '▁추억', '▁오', '카', '야', '마', '▁우', '치', '▁국제', '▁날씨', '▁조', '식', '▁설계', '▁대표', '▁', '찻', '집', '▁거', '북', '이', '▁정리', '▁구매', '▁내용', '▁원', '조', '▁진행', '▁예술', '제', '▁하', '마', '▁한번', '▁영상', '▁경', '관', '▁프로젝트', '▁숙', '박', '▁산', '도', '▁출발', '▁여행', '지', '▁기분', '▁개인', '▁사', '찰', '▁세계', '▁공간', '▁사', '누', '끼', '▁저장', '▁', '가', '면', '▁댓글', '▁확인', '▁기대', '▁아주', '▁직원', '▁보', '시', '▁', '붓', '쇼', '잔', '▁', '별로', '▁오', '이', '▁진', '에', '어', '▁오전', '▁콘텐츠', '▁종류', '▁야', '마', '▁성', '지', '▁덕', '분', '▁세', '토', '우', '치', '▁상', '점', '가', '▁엔', '젤', '▁', '로', '드', '▁구', '라', '시키', '▁', '낭', '만', '▁커피', '▁시', '골', '▁길', '이', '▁기념', '▁건축', '▁감동', '▁존재', '▁만난', '▁마지막', '▁기', '차', '▁인천', '▁내내', '▁', '곤', '피', '▁사랑', '▁세상', '▁체크', '▁전시', '▁프로', '필', '▁여름', '▁정', '육', '점', '▁이', '우', '환', '▁건물', '▁최대', '▁', '가', '이', '드', '▁', '하늘', '▁호', '수', '▁마', '녀', '▁배', '달', '▁후', '기', '▁교', '자', '▁중간', '▁역사', '▁이동', '▁라', '운', '지', '▁먼저', '▁제', '일', '▁기억', '▁', '도', '미', '▁', '갤', '러', '리', '▁스', '팟', '▁준비', '▁아빠', '▁거', '기', '▁소', '스', '▁무제한', '▁탑승', '▁순간', '▁무', '엇', '▁항공', '▁집중', '▁올해', '▁명', '소', '▁', '츠', '루', '▁미', '관', '▁지구', '▁발견', '▁', '닭', '다', '리', '▁한국인', '▁대', '여', '▁구', '경', '▁토', '리', '▁경비', '▁식사', '▁주변', '▁마', '는', '▁건축', '물', '▁종', '일', '▁곳', '곳', '▁음', '료', '▁돈', '키', '호', '테', '▁', '가', '야', '▁야', '시', '▁일본', '인', '▁테', '이', '▁구글', '▁나', '름', '▁감', '탄', '▁다른', '▁바', '삭', '▁근', '교', '▁운항', '▁소요', '▁점', '심', '▁다리', '▁만날', '▁시대', '▁그대로', '▁두', '번째', '▁휴', '무', '▁구', '석', '구', '석', '▁모', '토', '▁잠시', '▁새벽', '▁어제', '▁감', '상', '▁미', '슐', '랭', '▁규모', '▁문의', '▁', '뱃', '놀', '이', '▁이', '자', '▁사', '마', '▁미', '식', '▁연', '어', '▁본', '점', '▁현지', '▁엄마', '▁요리', '▁레', '일', '▁디', '저', '트', '▁수도', '꼭', '지', '▁볼', '거리', '▁스타', '▁그', '램', '▁공부', '▁참고', '▁자리', '▁자체', '▁', '과', '일', '▁사', '케', '▁포토', '▁맨', '홀', '▁속', '닥', '▁', '뱅', '기', '▁', '나무', '▁간', '장', '▁세', '이', '▁식', '감', '▁', '간다', '▁전혀', '▁식당', '▁예전', '▁블로그', '▁제공', '▁자', '루', '▁', '붓', '카', '케', '▁예정', '▁군', '데', '▁계', '란', '▁식', '료', '품', '점', '▁어', '묵', '▁조', '합', '▁취', '항', '▁홍보', '▁메', '리', '▁초', '밥', '▁나', '마', '▁비', '루', '▁별', '거', '▁도쿄', '▁오', '사', '카', '▁', '로', '컬', '▁도심', '▁', '빗', '자', '루', '▁모습', '▁마을', '▁거의', '▁야', '키', '토', '리',  ...
# 토큰 개수: 858
# ###############################
# 통영 텍스트 토큰화 결과: ['▁통', '영', '▁여행', '▁통', '영', '시', '▁경남', '▁카페', '▁바다', '▁맛', '집', '▁여름', '▁케이', '크', '▁추천', '▁시간', '▁거', '제', '▁디', '저', '트', '▁', '공원', '▁마을', '▁수', '국', '▁', '힐', '링', '▁코스', '▁축제', '▁', '펜', '션', '▁고양', '이', '▁고', '성', '▁투어', '▁벽', '화', '▁비', '진', '도', '▁행사', '▁마음', '▁사진', '▁이번', '▁한', '산', '▁풍', '경', '▁방문', '▁휴가', '▁여행', '지', '▁욕', '지도', '▁자연', '▁필수', '▁확인', '▁사람', '▁체험', '▁장소', '▁여유', '▁가능', '▁오', '션', '▁도시', '▁하나', '▁소개', '▁요', '트', '▁준비', '▁바로', '▁위치', '▁이', '순', '신', '▁아이', '▁매일', '▁하루', '▁감성', '▁해', '산', '물', '▁', '해수욕장', '▁친구', '▁불', '꽃', '▁대', '첩', '▁공간', '▁그', '램', '▁참여', '▁경', '상', '남', '도', '▁예약', '▁신청', '▁음식', '▁시작', '▁기간', '▁여기', '▁스타', '▁식당', '▁빙', '수', '▁운영', '▁팔', '로', '우', '▁분위기', '▁휴', '무', '▁추억', '▁광', '도', '면', '▁정말', '▁영업', '▁참고', '▁이벤트', '▁오늘', '▁진짜', '▁안내', '▁타고', '▁케이블', '카', '▁산', '책', '▁산', '양', '읍', '▁문의', '▁골', '목', '▁학교', '▁시장', '▁진행', '▁무료', '▁선', '상', '▁우리', '▁가장', '▁가족', '▁검색', '▁오후', '▁구', '안', '▁정', '원', '▁일상', '▁이용', '▁사', '량', '▁오전', '▁노', '을', '▁정보', '▁주문', '▁네이버', '▁여러분', '▁애', '견', '▁방법', '▁정', '량', '동', '▁디', '피', '▁관광', '▁관광', '지', '▁유', '람', '선', '▁오픈', '▁구', '가', '▁숙', '소', '▁모두', '▁욕', '지', '면', '▁생각', '▁저장', '▁국내', '▁댓글', '▁당첨', '▁다시', '▁데이트', '▁아이', '스크', '림', '▁직접', '▁할인', '▁바람', '▁광', '장', '▁푸', '른', '▁용', '남', '면', '▁여', '권', '▁', '와', '팡', '▁용', '호', '▁사랑', '▁개인', '▁일', '주', '▁투', '나', '잇', '▁중앙', '▁전통', '▁매력', '▁주', '차', '▁', '로', '컬', '▁지금', '▁날씨', '▁공연', '▁커피', '▁해양', '▁참가', '▁이야기', '▁메뉴', '▁', '라면', '▁거리', '▁해상', '▁계속', '▁', '도', '산', '면', '▁태', '그', '▁일', '원', '▁계획', '▁', '낭', '만', '▁보고', '▁포토', '▁동반', '▁자체', '▁카드', '▁', '재료', '▁정상', '▁레', '터', '▁잠시', '▁내용', '▁더', '위', '▁경험', '▁전', '복', '▁기분', '▁', '가', '게', '▁정도', '▁아침', '▁해', '안', '로', '▁구매', '▁주말', '▁봉', '수', '▁관람', '▁', '도', '깨', '비', '▁모든', '▁개별', '▁해', '변', '▁입장', '▁위해', '▁제대로', '▁활동', '▁카', '트', '▁명', '소', '▁그림', '▁도착', '▁미리', '▁연', '화', '▁예술', '▁문화', '▁요즘', '▁대형', '▁', '텐', '동', '▁처음', '▁버', '터', '▁크', '림', '▁마', '카', '롱', '▁한국', '▁제공', '▁때문', '▁프로그램', '▁마무리', '▁', '도', '산', '▁공유', '▁예정', '▁루', '지', '▁한번', '▁다음', '▁구', '이', '▁해도', '▁추가', '▁', '링크', '▁정리', '▁부대', '찌', '개', '▁호텔', '▁전화', '▁만', '월', '▁수', '제', '▁일', '시', '▁김', '밥', '▁지역', '▁한', '눈', '▁남', '해', '▁엄마', '▁', '꿀', '빵', '▁죽', '림', '▁거', '제도', '▁충', '무', '김', '밥', '▁제', '일', '▁포', '장', '▁지원', '▁관심', '▁이유', '▁경', '품', '▁남', '망', '▁지', '인', '▁동안', '▁저녁', '▁미', '수', '동', '▁케이', '▁프로', '필', '▁국', '물', '▁제작', '▁카카오', '▁채널', '▁위', '주', '▁역시', '▁전망', '대', '▁', '맥', '주', '▁매장', '▁', '센터', '▁보기', '▁청소년', '▁대상', '▁감', '상', '▁최대', '▁규모', '▁더욱', '▁자리', '▁계절', '▁마치', '▁아래', '▁정', '화', '▁티켓', '▁업체', '▁만날', '▁강', '추', '▁입', '구', '▁치', '즈', '▁선물', '▁소', '식', '▁홍보', '▁단체', '▁순간', '▁마지막', '▁구', '경', '▁국', '수', '▁대한민국', '▁마', '당', '▁', '객', '실', '▁자전거', '▁대', '여', '▁아', '르', '▁최고', '▁중앙', '시장', '▁기준', '▁물', '회', '▁사장', '▁재미', '▁', '에', '메', '랄', '드', '▁밤', '밤', '▁한', '산', '도', '▁캠핑', '▁어디', '▁산', '양', '▁', '브레이크', '▁', '타임', '▁소리', '▁기록', '▁', '햇', '살', '▁포인트', '▁레이', '스', '▁부', '스', '▁반', '려', '견', '▁미래', '▁뉴스', '▁기본', '▁패키지', '▁점', '심', '▁매', '점', '▁마감', '▁금', '요', '일', '▁일', '요', '일', '▁', '하늘', '▁모', '음', '▁지도', '▁그냥', '▁올', '여름', '▁기억', '▁스토리', '▁대표', '▁해', '저', '터', '널', '▁', '가', '야', '▁주', '소', '▁생', '선', '▁느낌', '▁가득', '▁손님', '▁인', '테', '리', '어', '▁라', '스트', '▁역사', '▁남', '동', '▁유', '자', '▁국', '적', '▁테', '라', '스', '▁바', '베', '큐', '▁변경', '▁온라인', '▁사용', '▁먹', '거리', '▁', '멍', '게', '▁여름', '밤', '▁또한', '▁최초', '▁공', '룡', '▁세계', '▁모집', '▁고민', '▁피', '로', '▁통해', '▁항', '구', '▁일', '몰', '▁유럽', '▁이상', '▁휴식', '▁라', '떼', '▁야외', '▁레', '저', '▁클럽', '▁', '낚', '시', '▁환', '급', '▁이제', '▁', '가', '면', '▁올해', '▁', '가', '성', '▁발견', '▁토', '요', '일', '▁', '가', '기', '▁공식', '▁반', '려', '동', '물', '▁부산', '▁택시', '▁식사', '▁여', '객', '선', '▁', '터미널', '▁야간', '▁수영', '▁발표', '▁선수', '▁다른', '▁인생', '▁충', '전', '▁구성', '▁', '쫄', '깃', '▁', '패밀리', '▁', '뫼', '골', '▁무', '엇', '▁산', '책', '로', '▁', '리조트', '▁허', '그', '▁동물', '성', '▁요리', '▁일반', '▁보호', '▁승', '선', '▁당', '일', '▁페', '스', '▁', '캔', '들', '▁상품', '▁세 ...
# 토큰 개수: 820

# %%
####전체 문장을 임베딩 했지만 이는 앞에서부터 512개 잘린 내용가지고 임베딩 한 것이므로
####유사도 값의 신뢰성이 없음. 

embedding_taka = embed_text(result_taka)
embedding_tongyeong = embed_text(result_tongyeong)

# 코사인 유사도 계산
similarity = cosine_similarity(embedding_taka.numpy(), embedding_tongyeong.numpy())

# 결과 출력
print(f"두 텍스트의 유사도: {similarity[0][0]:.4f}")

tokens_taka = tokenizer.tokenize(result_taka)
print(f"토큰 개수: {len(tokens_taka)}")
tokens_tongyeong = tokenizer.tokenize(result_tongyeong)
print(f"토큰 개수: {len(tokens_tongyeong)}")
# Out:
# 두 텍스트의 유사도: 0.8972
# 토큰 개수: 14640
# 토큰 개수: 22085

# %%
### 텍스트 요약 KoBART

# %%
from transformers import pipeline

# 한국어 감정 분석을 위한 모델 로드 (BERT 모델)
classifier = pipeline("sentiment-analysis", model="kykim/bert-kor-base")

# 텍스트 데이터가 문자열로 되어 있는지 확인
sentences = data_taka['caption_clean'][:50]

# 데이터가 리스트 형태로 되어 있다면
if isinstance(sentences, list):
    sentences = [str(sentence) for sentence in sentences]  # 리스트 안의 각 항목을 문자열로 변환

# 감정 분석 실행
for sentence in sentences:
    # 텍스트 길이가 너무 길면 잘라서 처리 (512 토큰 이하로:모델의 한계)
    result = classifier(sentence, truncation=True, max_length=512)
    
    sentiment = result[0]['label']
    confidence = result[0]['score']

    # 감정 레이블을 더 명확하게 변환
    if sentiment == "LABEL_1":
        sentiment = "POSITIVE"
    elif sentiment == "LABEL_0":
        sentiment = "NEGATIVE"

    # 결과 출력
    print(f"Sentence: {sentence}\nSentiment: {sentiment}, Confidence: {confidence}\n")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at kykim/bert-kor-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# Sentence: 디토는 지금 일본 다카마쓰 여행 중 작은 도시에서 큰 행복 찾고 싶다면 이 글 저장 꾹 공유 필수라구 다카마쓰에서 인생 우동 한 그릇 뚝딱 한 번 가면 무조건 또 가고픈 또간집 맛집 힐링 관광 스팟까지 한 번에 싹 정리해놨어 이제 뱅기 티켓이랑 숙소만 예약하면 바로 다카마쓰로 떠날 준비 완료 매장 주소가 궁금하다면 댓글을 확인해
# Sentiment: NEGATIVE, Confidence: 0.554742157459259
#
# Sentence: 일본 다카마쓰 우동투어 강나미 따라 간 당일치기 우동투어 하시모토 제면소 젓가락 그릇 필요 탱글탱글 맛있음 기대보다 좋음 아빠는 그냥 soso하지만 난 또 생각남 뭣도 없는데 이상하게 생각 남 나무젓가락 거기 있었는데 그래도 챙겨가세요 몇개 없었어요 간장 아주 조금만 넣고 비비고 모자르면 더 넣기 알고싶지않았음 마쓰바라 치킨카레우동 카시와텐 덴푸라 가루와 고추기름을 넣어서 비비면 더 맛있음 진짜 맛있어요 별이 다섯개 아빠도 나도 엄청 맛있다고 먹음 강나미 보고 왔냐고 주문 잘못하니까 알려주고 아주아주 매운맛인데도 안 매움 또 먹고 싶어요 카시와텐은 나와요 꼭 드세요 촉촉하고 튀김이 얇아요 코가네 세이멘쇼 우동 레스토랑 냉우동 온우동 소스에 생강 파 꼭 넣기 얼음이 저 만큼 나오지는 않아요 따뜻한 것과 차가운 것 둘다 좋은데 냉우동은 와사비를 더 추천 온우동은 생강을 많이 넣어야 맛있음 한국말 잘 하는 외국인직원이 있어서 소통 너무 편히고 저는 튀김가루 같이 씹히는 식감이 좋아서 튀김가루도 많이 넣었어요 모리야우동 Kagawachokawanaihara Takamatsu Kagawa Japan 튀김우동 미니도 있어요 기사님이 추천해주신 모리야우동 분위기 좋고 맛있었음 삼삼오오 오는 사람들이 많았고 체인점입니다 큰 것도 있지만 미니우동으로 먹었는데 요기만 간다면 큰거 추천 미니도 여성분들이 드시기는 딱 좋음 튀김도 바싹하니 맛있었음 국물은 원하는 양만큼 넣으면 되는데 전 조금 남기고 다 넣었는데도 짜거나 자극적이지 않았음 공항이랑 진짜 가까움 여기도 강추 셀프우동 노부야 문 닫는데 저는 마감했더라고요 ㅠㅠ 가실분들 미리미리 가시는 게 좋을 것 같아요 택시 합의보시고 움직이세요 강나미 따라 공항에서 미리 협의하고 타시는 걸 추천 가격을 깍거나 할 수는 없고 고정인 듯 해요 회사와 연락해서 이야기 나누셨어요 기사님이 전 부탁드렸고 어딜 얼마나 가는지는 전혀 문제 없이 시간안에 다니시면 됩니다 처음 탄 택시비가 정도 나왔도 타고 택시가 돌아가서 깍아주셨어요 이 정도로 계산 했을때 당일치기 시간싸움은 시간협의가 좋을 것 같아요 정말 택시가 보이지 않아서 잡기 어렵지만 가게에서 택시를 불러쥬셔서 바로 탔는데 가게마다 택시를 불러달라 하시면 제 동선안에서는 조금은 싸게 다닐 수 있는데 가뜩이나 바쁜 직원분께 실례가 되는 일은 없는게 좋을 것 같고 중요한 건 기사님이 지름길로 안 가시면 역시나 택시비 폭탄 맞을 각오 하셔야해요 #우동 #udong #일본우동 #강나미우동투어 #일본우동 #일본우동투어 #다카마쓰 #다카마쓰우동투어 #당일치기우동투어 #다카마쓰택시 #일본택시 #japan #japanudong #일본여행 #travelgram #travel #japanfood #japantravel #우동맛집 #하시모토제면소 #마쓰바라 #코가네세이멘쇼 #모리야우동 #노부야우동 #강남우동맛집 #강남일본우동 #강나미우동 #당일치기다카마쓰 #카가와현 #카가와현우동
# Sentiment: POSITIVE, Confidence: 0.5206579566001892
#
# Sentence: 일본 다카마쓰에서 꼭 들려야 할 붓쇼잔 온천 노천탕과 실내 온탕 냉탕으로 구분되어 있으며 샴푸 바디워시 등 용품들은 비치되어 있어요세안용 비누나 로션은 없음 중고서적을 판매하기도 하고 내부 식당도 있어서 힐링하면서 만족스러운 시간을 보낼 수 있었어요 첫번째 사진의 부채가 붓쇼잔패스권인데 다카마쓰칫코역 역무원에게 구매하였고 당일 기준 다카마쓰칫코역에서 붓쇼잔역까지 무제한 탑승이 가능하며 온천 입장료도 포함되어 있어서 구매하는게 좋아요
# Sentiment: POSITIVE, Confidence: 0.5994763374328613
#
# Sentence: 토토로 #일본지브리샵 #지브리샵 #다카마쓰지브리 #다카마쓰상가 #다카마츠 #다카마츠여행 #일본여행
# Sentiment: POSITIVE, Confidence: 0.5774778723716736
#
# Sentence: 야돈우동붱 #다카마쓰 #다카마쓰여행 #일본 #일본여행
# Sentiment: POSITIVE, Confidence: 0.5736289620399475
#
# Sentence: kotodenbus 난 고토덴 버스 좋았어
# Sentiment: NEGATIVE, Confidence: 0.5177863240242004
#
# Sentence: 다카마쓰 여행 처음으로 단둘이 함께 떠났던 여행 내 컨디션이 별로였음에도 불구하고 매 순간이 즐겁고 포근했던 여행이었다 무엇보다 끊임없었던 계단은 절대 잊지 못하지 오랜만에 예전 같은 여행을 한 것 같아 마음이 설렜던 일본 소도시 여행이었다 세토대교 고토히라궁 리쓰린 공원 자세한 이야기는 블로그에 있어요 #일본소도시여행 #일본여행 #다카마쓰여행 #다카마쓰
# Sentiment: POSITIVE, Confidence: 0.6721422076225281
#
# Sentence: 보물섬 투어 다카마츠 자연 속 힐링 우동과 예술의 섬 다카마츠 여행 패키지 오이리 토핑의 소프트 아이스크림 제공 일본 전통 온천욕 보물섬 투어와 함께하는 힐링 다카마츠 여행 자세한 내용은 홈페이지 확인 #다카마츠 #시고쿠 #사누키우동 #오이리 #온천 #일본
# Sentiment: POSITIVE, Confidence: 0.6401811838150024
#
# Sentence: 다카마쓰 우동 당일치기 NO 최소 해야 하는 이유 강남kangkangnam님이 다카마쓰에 우동 먹으러 당일치기로 다녀왔다길래 우동 정보 쌈뽕하게 풀어봅니다 당일치기 가능 하지만 진에어 데일리 항공편이 오후 시간대로 조정되면서 오전에는 에어서울airseoul_official로 가고 오후에는 진에어jinair_lj로 돌아오는 당일치기가 가능해졌습니다 생각만 했던 걸 직접 실현하시다니 WoW 하지만 이상 머물러야 하는 이유 경험할 우동이 훨씬 많고 생각보다 다카마쓰에서 할 게 많다 이번 콘텐츠는 우동에 집중해 소개해봅니다 우동집을 고르는 기준 우동의 종류 가케우동 가마타마우동 자루우동 붓카케우동 냉우동 등 선택의 재미 가게 스타일 셀프 조리 정통 레스토랑 제면소 등 올해도 최소 이상 우동투어를 운영할 예정인데요 카가와현에는 우동집이 무려 이상이라죠 우동 투어를 다녀온 입장에서 콘텐츠용으로 몇 군데를 추천해볼게요 카가와현 우동 맛집 리스트 ① 야마고에 우동 가마타마날계란을 얹는 우동의 원조 가게 ② 야마시타 우동 붓카케 우동의 원조 히야아츠히야아츠 선택 가능 ③ 스자키 식료품점 식료품점 옆 숨겨진 우동 명소 메뉴 ④ 오가타야 우동 쇼유우동 원조 직접 무를 갈아 넣어 먹는 재미 ⑤ 히노데 제면소 영업시간 단 카가와에서 가장 저렴하지만 면발은 최상급 ⑥ 나가타 in 카노카 가마아게 우동의 최강자 ⑦ 가모우 우동 미쳤다는 말밖에 안 나오는 곳 ⑧ 츠루마루 다카마쓰 카레우동의 성지 야간 영업 ⑨ 고에몬 근처에 위치한 흑카레쿠로카레 우동 명소 ⑩ 우동 바카이치다이 가마버터우동이 시그니처 영업시간이 길어 접근성 좋음 ⑪ 마쓰시타 제면소 깔끔한 가케우동이 매력적 ⑫ 야마다야 멋진 정원이 있는 우동집 상견례 장소 가능 ⑬ 카와후쿠 자루우동 원조 가게 ⑭ 치쿠세이 치쿠와어묵튀김와 우동 조합이 예술 ⑮ 사누키 라멘 하만도 우동면으로 만든 라멘 독특하지만 맛있음 근데 이게 끝이 아님 코로나 이전에는 곱창우동 파우동 샤브샤브우동 같은 특이한 메뉴도 많았지만 지금도 여전히 카가와현에는 우동 맛집이 넘쳐납니다 추천하고 싶은 우동집은 더 많지만 원하시면 저의 우동 지도 링크를 보내드립니다 모리의 우동 스토리 에어서울 다카마쓰 첫 취항 때부터 방문 왕복 프로모션 덕분에 시작된 인연 우동에 미쳐서 일본정부관광국JNTO의 줌인재팬 홍보 캠페인까지 진행면업일치아니 덕업일치 결국 우동투어까지 운영하는 중 진짜 우동밖에 없나요 놉 올해는 열리는 세토우치 예술제가 진행되는 해라 콘텐츠가 풍부한 만큼 우동만 있는 곳이라고 생각하지 않아도 됩니다 #우동에미치다 #우동투어 #일본여행 #다카마쓰
# Sentiment: NEGATIVE, Confidence: 0.5226287841796875
#
# Sentence: 일본 시코쿠 다카마츠시 다카마츠역앞 우동집 메리켄야 #일본 #시코쿠 #다카마츠 #다카마츠역앞 #메리켄야 #우동 #우동순례 #사누끼
# Sentiment: POSITIVE, Confidence: 0.6272031664848328
#
# Sentence: 카이센 우마이몬야 하마카이도 카지야마치점 해산물 전문 이자카야 회를 좋아하는지라 회는 여러종류 나오는걸 시켰고 초밥은 참치 덕분에 둘이서 배터지게 먹고 나왔네요 Kajiyamachi Takamatsu Kagawa 일본 #일본여행 #다카마쓰 #다카마츠 #우동 #마실이여행
# Sentiment: POSITIVE, Confidence: 0.6621172428131104
#
# Sentence: 리쓰린 공원 안에도 기린 나마비루가 아 맥주한잔의 힐링 ᴗ 와 이제 슬 덥다다다다다다다다닫 #ㅎㅎ부부여행 #ㅎㅎ부부다카마쓰여행 #다카마쓰 #다카마쓰여행 #리쓰린공원 #기린나마비루
# Sentiment: POSITIVE, Confidence: 0.5430994629859924
#
# Sentence: 상점가만 둘러보는데 반해버린 다카마쓰 저녁은 하나마루우동에서 해결하기
# Sentiment: POSITIVE, Confidence: 0.5315839648246765
#
# Sentence: 쇼도시마 엔젤로드 다음 스케쥴을 취소해서라도 더 머물고 싶었던 곳 #쇼도시마 #엔젤로드 #다카마쓰여행 #한번더갈꺼야 #가족여행
# Sentiment: POSITIVE, Confidence: 0.6593875885009766
#
# Sentence: 다카마쓰 여행 다카마쓰역 구라시키 둘째날은 전부터 가보고 싶었던 구라시키 반나절 투어 다카마쓰 여행의 좋은점은 근처에 갈수 있는 도시들이 많다는 것이다 푸릇푸릇 할때 더 예쁠것 같긴 하지만 미관지구는 소도시 투어의 낭만을 충족 시키기에 좋은곳이었다 걸어다니며 상점 구경도하고 맘에드는 카페를 발견하고 커피 홀짝이다가 셋이나온 사진 한번 찍어 보겠다고 용을 쓰다가 건진 사진에 행복해하고 별거 아닌 일들이 별거가 되는 일들이 여기선 허다하다 전반적으로 음식값이 싼것도 너무 마음에 드는 포인트 남짓한 오코노미야키 이면 먹을수 있는 맛있는 우동 안되는 나마비루 라니 둘째날의 마무리는 우동말고 다카마쓰에서 유명한 닭다리구이 나마비루로 마무리 너무 맛있어서 똑같은거 두개시킴 ku_wanderlust heeyeon_choi #슬기로운다카마쓰여행 #다카마쓰 #구라시키 #구라시키미관지구 #Kurashiki
# Sentiment: POSITIVE, Confidence: 0.6136983036994934
#
# Sentence: 엉덩이박살나는중#다카마쓰여행
# Sentiment: POSITIVE, Confidence: 0.549824595451355
#
# Sentence: 단돈 떠나는 우동야돈 여행 일본 다카마쓰 코스 완전 정복 한국인 없는 찐 시골 감성에서 힐링하고 페리 타고 쇼도시마까지 탐방 알차다 알차 도쿄 오사카에 질렸다면 이번엔 진짜 일본 로컬로 떠나볼까 다카마쓰 어때 다카마쓰 코스 다카마쓰 도착 패스권 구매 ㄴ 다카마쓰 지하철역 근처에서 지하철 티켓 온천 입장권이 포함된 패스권 구매 붓쇼잔 온천 ㄴ도심에서 지하철로 거리 소도시 감성의 조용한 노천탕 단토츠라멘 ㄴ고기숙주진한 육수가 어우러진 로컬 맛집 쇼도시마 도착 야돈 페리 탑승 올리브공원 ㄴ키키빗자루 무료 대여 가능 인생샷 예약 ㄴ올리브 소프트아이스크림도 꼭 먹어봐야 해 진짜 올리브 맛남 오오미네우동가게 ㄴ쫄깃한 면발 직접 우동 담아주는 모습 눈앞에서 볼 수 있음 헬로사이클링 자전거 투어 ㄴ전동자전거라 전혀 힘들지 않아요 바닷마을 풍경도 찬찬히 구경해보기 엔젤로드 ㄴ하루에 단 길이 열리는 로맨틱한 장소 연인끼리 손잡고 걸으면 소원이 이루어진다는 전설 다카마쓰항 귀환 야돈 페리 탑승 다카마쓰 이온몰 하마스시 ㄴ가성비 최고 회전초밥 맛집 거의 모든 접시 요시토리 ㄴ일본 여행의 마무리는 역시 야키토리생맥주 리쓰린공원 ㄴ일본 정원 중 하나 ㄴ연못돌다리정자 등 그림 같은 뷰 가득 마루가메마치 상점가 일본 감성 쇼핑거리 도시락 먹방 마트 마트에서 파는 신선한 초밥 도시락 다카마쓰 공항 출국 전 우동 한 그릇 ㄴ공항 내 우동 자동 자판기 체험 가능 다카마쓰 총경비 정리 기준 대략적인 가성비 비용 항공권 진에어 다카마쓰 직항 왕복 숙소 기준 인당 가격 에어비앤비 교통비 버스 지하철 페리 헬로사이클링 포함 식비 우동라멘초밥야키토리 등 총합 약 쇼핑이나 식사로 a 가능 우동이나 스시 등 저렴한 식사로 식비 세이브 에어비앤비로 숙소비 세이브 Find with us 내용에 공감하셨다면 좋아요 언제든지 다시 보고 싶다면 저장 주변 사람들도 알려주고 싶다면 공유 매일 올라오는 여행 꿀팁을 보고 싶다면 팔로우 눌러주세요 사진영상 제공해주신 모든 분들께 감사합니다 #여행톡톡 #여행톡톡_해외 #일본여행 #다카마쓰여행 #카가와현여행 #쇼도시마여행 #일본소도시여행 #가성비일본여행 #일본여행코스 #일본소도시추천 #일본자연여행 #일본지방여행 #우동성지 #일본우동투어 #다카마쓰우동 #다카마쓰맛집 #붓쇼잔온천 #쇼도시마 #올리브공원
# Sentiment: POSITIVE, Confidence: 0.5896334052085876
#
# Sentence: 나의 오랜 친구들과 같이 떠난 여행 애들 키우고 각자의 삶에 바빠 그리 시간 내기가 힘들더니 이제서야 한숨 돌리고 모든 일을 다 재쳐두고 같이 떠난 기념적인 여행이다 각자 여행은 다니지만 한꺼번에 떠나기란 진짜 떠나기 전날 까지 조마조마 우여곡절이 많았다 결론적으로는 너무나도 신나고 힐링되고 즐거웠던 여행 각자 일본은 많이 가서 같이 안가본 곳을 고르자니 다카마츠 나오시마로 결정되었다 일본 안에서도 변방 많이 찾지 않는다 하는 곳이라 한없이 한적하고 여유로웠다 특히 나오시마는 섬하나 전체가 박물관 이라 할 정도로 여러 박물관과 자연경관이 어울어져 종교적 경건함 까지 느낄수 있었던 너무 좋은 경험이었다 안도 다다오의 건축물이 #모네 #제임스터렐 #월터드마리아 작품과 만나 강렬한 빛과 건축과 예술품의 합의 경지가 영혼의 울림까지 끌어 올렸다 전혀 사전지식 없이 간 박물관이라 나는 거의 충격에 가까운 감동을 만났었다 #베네세하우스 뮤지엄도 #안도다다오 의 작품으로 호텔과 함께 하는 작품들이 주위의 경관과 더불어 끊임없이 말을 건네 온다 박물관과 박물관을 연결하는 셔틀이 있지만 우리는 최대한 걷고 자연을 느끼며 하루종일을 지냈다 해안가의 #쿠사마야요이 의 호박들도 넓은 바다를 배경으로 하니 그 존재감이 대단했고 폐가를 개조해서 만든 이에프 프로젝트도 우리가 앞으로 다가올 현실의 길을 좀 보여 주는듯 했다 내 일정이 바빠 난 어디를 가는지도 인지 하지 못한체 따라 와서인지 가는 곳곳마다 기대 이상의 즐거움과 감동이었다 아마도 몇십년을 함께한 친구들과 함께 하고 서로를 너무 잘 아는 사이이기 때문에 여행 스켈줄 안에서도 삐걱 거림이 없다 이리 합이 맞는다는 것도 같이 삭히고 삭힌 시간의 선물이겠지 다카마츠 는 작은 시골 동네이지만 그 조용하고 고즈적함이 주는 안정감은 곳곳에 스며 있어서 우리도 부드럽게 따라가게 된다 특히 리쯔린 공원은 일본 정원의 정수를 보는듯 하여 좀 과장해서 말해 이승과 저승의 경계 어디쯤이 아닐까 하는 생각이 들게도 했다 요즘 일본을 가면 물반 한국사람 반이라던데 우리는 그래도 조용한 곳에서 더할수 없이 차분하고 즐거운 여행을 하고 온듯 하다 이제 시작이다 또 어디를 갈 것인가 #일본여행 #친구들여행 #다카마츠 #나오시마 #이게얼마만의일본여행 #이제큰일이다계속나갈듯 #고즈넉한동네 #쓰레기섬이박물관으로 #오사카에서한시간반 #여행스타그램 #풍경스타그램
# Sentiment: POSITIVE, Confidence: 0.6422008872032166
#
# Sentence: 총 경비 일본 여행 항공권 숙박 식음료 쇼핑까지 뿌신 우리 둘 우정여행 행복감은 비용에 비례하지 않는다 다카마쓰에서 해야할 것 우동집 뿌시기 우동집만 우동의 본 고장 자전거 타고 동네 한 바퀴 안하는 공용자전거 자전거 도로가 잘 돼있는 도시라 자전거 타기 꿀잼 일본 공원인 리쓰린 공원 공원 안에 있는 카페에서 다도 체험하기 근거리 온천 즐기기 붓쇼잔 온천 포카포카 온천 유명 다카마쓰 시내에서 버스로 거리 동네에서 러닝하기 인도는 넓고 사람은 없는 도시 시티런 하라고 만든 동네가 아니냐며 항공권 에어서울 왕복 숙소 JAQ 호스텔 기준 식비 기준매 끼니 우동 먹어서 저렴 쇼핑 돈키호테에서 팩 하나 오차즈케 자전거 대여 가능한데 모르고 비싼거 빌림 기타 교통비 버스 전철 이용 주차비 인천공항 장기주차 다카마쓰 일본 #일본여행 #다카마쓰 #다카마쓰여행 #여행에미치다
# Sentiment: POSITIVE, Confidence: 0.6696599125862122
#
# Sentence: 아혹해서 또 예약 ㅋ #에어서울 #특가 시간이 구경이나 할까하고 들어갔더만 한창 지난상태라 대기시간이 얼마나 걸리려나 했는데 멀쩡하네 보고 있다가 움찔움찔 하다보니 가격이 아주 훌륭한 아니 담에 #다카마츠 가야지 했었는데 생각도 안하고 또 #후쿠오카 찍었네 ㅇㅁㅇ 가야지그치가야지
# Sentiment: POSITIVE, Confidence: 0.5578966736793518
#
# Sentence: #여행스타그램 #일본여행 신 야시마 수족관 가는 길에 통과하게 되어 있는 옥도사 도시부터 바다까지 이어지는 전망이 진심 최고 #시코쿠여행 #카가와현여행 #다카마쓰여행 #여행그램
# Sentiment: POSITIVE, Confidence: 0.6453925967216492
#
# Sentence: 이런 거 한국에서는 흔하지 않다고 했더니 다카마쓰에서 만난 일본인 친구가 믿지 못하겠다고 했다 그 친구 지금 한국에 와 있다 #곧_만나러_갑니다 #reco_ig #japanstreets
# Sentiment: POSITIVE, Confidence: 0.5573911070823669
#
# Sentence: #우동 #다카마츠 가마버터를 처음 시작한 곳이라고 한다 그리고 게살크림고로케
# Sentiment: POSITIVE, Confidence: 0.5749813914299011
#
# Sentence: 나는야 때와 장소를 가리지않는 사진부탁 폭격기 #혼또니 #스미마셍 니뽄스러운 분위기에서 마챠 한 잔 쿠다사잇 키쿠게츠테이 리쓰린공원 내에 위치 말차 set 센차 set 리쓰린 공원 입장료 #키쿠게츠테이 #리쓰린공원 #다카마쓰 #일본소도시여행 #일본여행
# Sentiment: POSITIVE, Confidence: 0.6140770316123962
#
# Sentence: 다카마쓰를 만나러 갑니다 #다카마쓰
# Sentiment: POSITIVE, Confidence: 0.5692634582519531
#
# Sentence: #일본#다카마쓰여행
# Sentiment: POSITIVE, Confidence: 0.6765282154083252
#
# Sentence: # 우동의 도시답게 온통 우동집 뿐이었던 다카마쓰에서 리쓰린 공원은 다카마쓰의 보배 같은 곳이다 우동보의 덴뿌라 우동은 정말 인생 우동 후르츠 산도도 너무 맛있었규 특히 메론 마지막날 아침으로 먹었던 크로크마담도 완벽했음 #다카마쓰여행 #우동보 #리쓰린공원 #타마모공원 은 별루
# Sentiment: POSITIVE, Confidence: 0.6581377387046814
#
# Sentence: 우동만 유명한 줄 알았던 다카마쓰 알고 보니 기념품 천국 다카마쓰 여행 가면 무조건 쓸어 담아야 할 쇼핑 리스트 공유 귀여움 감성 맛까지 챙긴 쇼핑템들로 여행의 마무리를 완벽하게 만들어보자 hwg_official 팔로우하고 더 많은 여행 꿀팁 정보 받아보세요
# Sentiment: POSITIVE, Confidence: 0.5910847187042236
#
# Sentence: 해외라 설렜어욤
# Sentiment: POSITIVE, Confidence: 0.594389796257019
#
# Sentence: #Takamatsu #다카마쓰 다카마쓰의 파노라마 뷰를 한눈에 담은 #심볼타워전망대 다카마쓰역 바로 앞 세토나이카이와 섬들이 눈앞에 펼쳐지는 이 매력적인 전망대는 낮부터 밤까지 언제 방문해도 좋아요 무료라 더 행복한 꿀스팟 #일본여행 #다카마츠여행 #japantravel #takamatsutrip
# Sentiment: POSITIVE, Confidence: 0.6759260892868042
#
# Sentence: 혼자 낭만 다카마쓰 여행 우동의 본고장이라 우동 천국 #다카마쓰 #일본 #우동
# Sentiment: POSITIVE, Confidence: 0.5283493995666504
#
# Sentence: 다카마쓰 혼키돈쿠 구글 연속 우동을 먹으려 했지만 이건 아닌것 같아서 선택 샐러드 드레싱도 돈까스 소스도 다양하게 먹을 수 있고 정식에 나오는 국도 톤지루로 제대로 레몬하이랑 먹으면서 계속 맛있다 생각함 우동바카이치다이 구글 갓 삶은 우동면에 버터 한조각 그리고 신선한 계란 톡 쇼유를 조금씩 뿌려서 잘 섞어서 냠 소스를 적게뿌리면 담백함과 통후추의 맛이 느껴지며 나름 맛있고 소스를 더 뿌려 튀김이랑 같이 먹으면 그것도 맛있고 ㅠㅠ 호네츠키도리 란마루 구글 다카마쓰의 메인 상가는 저녁이 되야 더 활기찬 느낌이다 이곳 저곳 대왕닭다리를 구어서 판다 역시나 가게에서 먹고 싶었지만 ㅜㅜ 웨이팅까지 있어서 포장 주문하고 기다리면 야들야들 짭잘한 호네츠키도리가 내 손에 하이볼과 함께 냠 역시나 대 성 공 #다카마쓰 #다카마쓰맛집
# Sentiment: POSITIVE, Confidence: 0.5713756084442139
#
# Sentence: 다카마쓰 우동 투어 다카마쓰가 있는 카가와현은 양질의 밀 바다 소금 멸치의 주요 산지 좋은 간장 덕분에 우동이 맛있기로 유명해요 머리가 우동으로 가득 찬 우동뇌 캐릭터가 있을 정도로 우동에 진심인 곳이랍니다 ㅋㅋㅋㅋ 사누키 우동 일본 카가와현과거 이름 사누키국 일대에서 생산되는 우동 강남님이 카가와현에 당일치기로 가서 동안 우동 다섯 그릇을 먹으며 감탄하는 영상이 있는데요 남자친구가 그걸 보고 하루 날 잡고 우동만 먹는 계획을 세워버렸답니다 사실 저는 밀가루 음식을 잘 소화하지 못해서 우동을 안 좋아하는데 남자친구가 신나있는 모습을 보니 거절하기가 쉽지 않더라고요 그렇게 저희의 하루 우동 다섯 끼 미션이 시작되었답니다 첫 번째 우동 #코가네제면소 도착하자마자 설렘 폭발한 남친을 따라 들어간 코가네제면소 첫 메뉴는 면을 쯔유에 찍어먹는 냉우동이었는데 와 진짜 한 입 먹자마자 눈이 번쩍 뜨이는 맛이었어요 갓 뽑은 가래떡처럼 탱글탱글하고 쫠깃쫠깃한 면발에 걱정은 순식간에 사라지고 한 젓가락 먹을때마다 감동을 받았답니다 하루에 우동 다섯 끼 가능할수도라는 생각이 스쳐지나갔어요 ㅋㅋㅋㅋ 두 번째 우동 #하시모토제면소 강남 유튜브에도 나왔던 하시모토제면소애서는 봉지우동을 먹을 수 있어요 면이 살짝 까끌하면서도 찐한 밀가루 맛이 느껴지는데positive 이게 진짜 맛있는 밀가루 맛이에요 우동 본연의 고소함과 씹는 재미에 두 그릇째인데도 계속 들어가더라고요 세 번째 우동 #카가와야모토텐 귀여운 야돈유부우동을 파는 카가와 야모토텐 아야가와점을 방문했어요 따끈한 국물우동카게우동에 부드러운 유부 그리고 대망의 튀김 부스러기까지 앞서 두 번의 우동을 먹고 나니까 우동에 대한 눈이 높아진건지 뭔지 저에게는 우동맛이 특별하지는 않았어요 근데 이곳 튀김 부스러기는 다른 곳에 비해 바삭함과 고소함이 미쳤습니다 옆 테이블의 일본분이 우동 위에 튀김 부스러기로 탑을 쌓으셨더라고요 ㅋㅋㅋ 그 이유를 알게 되었습니다 허허 네 번째 우동 #나카노우동학교 배는 부르지만 멈출 수 없는 우동의 유혹 네 번째는 무려 우동 학교였어요 직접 우동 만드는 법을 배우고 우리가 만든 우동을 먹을 수 있는 곳이라 기대가 컸답니다 근데 반죽을 시작하자마자 선생님이 갑자기 탬버린을 나눠주시는 거예요 우동 만들려고 왔는데 왜 탬버린 저희 이상한 곳에 온 것 같아요 다음 우동은 어떤 맛일지 과연 저희는 우동 다섯끼를 다 해치울 수 있을지 다음 편에 계속됩니다 #다카마쓰 #다카마쓰여행 #커플여행 #우동투어 #사누키우동 #우동맛집 #여행툰 #대학원생
# Sentiment: POSITIVE, Confidence: 0.6304065585136414
#
# Sentence: 혼자 일본여행 #다카마쓰 첫째날 출발 이틀전에 항공권 끊고 하루전에 호텔 예약해서 대충 떠났던 급여행 성공적 무계획으로 떠난건 처음이라 되는대로 다니고 쉬다오자 했는데 기대보다 알찼던 간만의 혼자여행 기록 입국하자마자 호텔로 이동해서 짐 맡겨두고 다카마츠 근교여행 필수코스 #구라시키 미관지구로 기차타고 슝슝 옛날 일본 분위기 만끽하며 발걸음 가는대로 걸어보는 혼자여행 이 맛 첫끼는 지나가다 냄새에 홀려서 들어가서 먹은 일본카레 Oishi #cafemiyakeshouten 아직까진 한국사람 마주칠 일 거의 없는 곳이라 여유로운 혼자여행 원하신다면 #일본소도시여행 #다카마츠 강려크하게 추천갈겨요 오카야마현 구라시키 미관지구 인천다카마쓰 매일 운항 airseoul_official 다카마쓰역구라시키역 기차로 약 소요 환승 해야하니까 정신 똑띠 차려야하며 버스로 환승하면 조금 더 저렴하고 빠름 편도 정도 혜트리 첫 해외여행지가 이 곳 다카마츠였는데 혼자서 다시 가니까 전 추억도 떠오르고 기분 몽글몽글 아련데쓰 담에 꼭 함께해요 miss u ok_guri #takamatsu #kurashiki #okayamatrip
# Sentiment: POSITIVE, Confidence: 0.6311657428741455
#
# Sentence: ෆ 드디어 마지막 피드 화장품 쇼핑은 날 행복하게해 셋째 날 나오시마섬 가려고 했는데 쇼핑을 별로 못해서 나오시마섬 포기 하루종일 쇼핑하느라 정신없이 걸어다녔더니 사진이 별로 없다 암튼 다카마쓰 여행 사진 끝 급마무맄ㅋㅋㅋㅋㅋ 여행 사진은 밀리지않고 그때그때 올리고싶었는데 매번 몇 개월씩 지나고서야 올림ㅋㅋ 하 초딩때 방학일기 밀려쓰던 버릇 어디 안가네 #다카마쓰여행 #혜징료코
# Sentiment: POSITIVE, Confidence: 0.6556804180145264
#
# Sentence: ෆ 다카마쓰 여행 한국 오고나서 세번째 일본여행인데 효도여행 아닌 개인 여행은 처음 대도시는 많이 가봐서 이번엔 소도시로 정했다 그중에서도 우동이 유명해서 우동현이라고 불리는 다카마쓰 여행 내내 계단의 후유증에 시달릴것도 모르고 신나게 곤피라상 계단 올라간 나 첫 날 고토히라에 도착해서 점심으로 먹은 첫 우동 짱맛 곤피라상 가는 길에 먹은 파 아이스크림 이것 또한 짱맛 계단이 곤피라상에 갔다 정도까지만 올라갔는데도 여행 내내 다리 아파서 죽는줄ㅠㅠㅋㅋ 휴족시간 스트레칭을 아무리해도 붓기가 안빠짐 여행하면서 이런 적 처음인데 아무래도 계단때문인듯 괜히 무리하지 말자 신사 갔으니까 오마모리 사기 내꺼 유진이꺼 재은이꺼 샀는데 짱귀염 료칸 가는 길에 본 추억의 이치방시보리 쇼쨩 #다카마쓰여행 #고토히라 #곤피라상 #이와노야우동 #혜징료코
# Sentiment: POSITIVE, Confidence: 0.6234831809997559
#
# Sentence: 다카마쓰 사진털이 다카마쓰 역에서 타고 정도면 도착할 수 있는 오카야마 오카야마역에서 정도를 걸으면 일본의 정원인 고라쿠엔을 만날 수 있다 사진에 보이는 다리를 건너면 까마귀 성으로도 불리는 오카야마 성이 있는데 입장권을 내지 않고 성터만 둘러봐도 충분 자연경관을 좋아한다면 가볼만한 일본 여행지 #여행사진 #오카야마 #다카마쓰 #고라쿠엔 #오카야마성 #일본여행 #sony #snap
# Sentiment: POSITIVE, Confidence: 0.6632708311080933
#
# Sentence: II 도하연즈네 온도가 뭐던간에 마냥 행벅했던 다카마쓰 덥다고 떨어지면 떨어져서 더운거라고 가스라이팅 당했던 날 #다카마쓰 #폭염주의보
# Sentiment: POSITIVE, Confidence: 0.5757145881652832
#
# Sentence: 내일 그냥 떠나볼까 해서 아무계획없이 떠난 다카마쓰그래서 여행내내 도시이름 못외운 지유지운 진짜 예전 시대의 다방이 그대로 보존되어있는 킷사텐 온몸이불탔던 리츠린공원 의사소통안되서 먹은 무한리필 야끼니쿠근데 너무 맛있 #다카마쓰 #Takamatsu #오카야마 #Okayama
# Sentiment: POSITIVE, Confidence: 0.6229069232940674
#
# Sentence: 시코쿠에는 사찰을 순례하는 오헨로 순례길이 있다 야쿠리지는 오헨로의 사찰로 종종 하얀 복장에 삿갓을 쓰고 순례길을 걷는 분들을 만날 수 있다 에마에 소박한남부장은 거창하게 사업번창 소원을 적고 조용한 경내를 걸어본다 #햄식이밤식이_다카마쓰 #다카마쓰#다카마쓰여행#야쿠리지
# Sentiment: POSITIVE, Confidence: 0.6746314764022827
#
# Sentence: 우동 먹은 일본여행 썰zip 정보 포함 네 우동만 먹고 왔습니다 오전 아침 비행기라 한그릇만 먹었고 먹었네요 오전 다 먹엇냐구요 잘못시킨 한그릇 빼고 설거지했습니다 제가 이번 여행으로 다녀온 다카마쓰는 일본 카가와 현이라는 곳에 있고 우동현이라고 불릴 만큼 우동 장인과 맛집이 많은 곳입니다 저는 이번이 두번째 우동먹으러 간 다카마쓰 여행이었고 모두 우동투어 대장인 모리형 traveltvkr 을 따라서 다녀왔습니다 사진은 안올라가서 추후 릴스 영상으로 모든 우동 영상을 풀겠습니다 다녀온 우동집 정리 총 우동집 우동 식료품점 가케우동 새우튀김 가리아케 먹자마자 미친놈인데 외침지금 생각해보니 여기가 오전에만 영업 식료품점에서 파는 감성 또한 좋음 나카무라 우동 가마타마 우동 무라카미 하루키 님이 사랑한 우동집왜 사랑한지 알겠음 무언가 식감이 다르게 느껴지는 곳 나가타 인 카노카 우동 가마아게 우동 찰스러운 면발첫 투어 당시 가장 임팩트가 컸던 곳 이게 우동이야 싶지만 먹어보시면 감탄사가 절로 사누키 라멘 하만도 우동 라멘 우동과 라멘 사이 깔끔한 국물맛이 일품 그리고 차슈도 맛있음 야마고에 우동 가마타마 우동 오뎅 튀김 두번째 방문 가마타마 우동의 원조집 멘도코로 와타야 마루가메점 니쿠 우동 소고기 듬뿍 푸짐한 한그릇이 인상적 체인점으로 운영중이었음 히노데 제면소 우동 카가와에서 오래된 우동집 면발 기준 하루 영업가보시면 왜인지 압니다 가모우우동 우동 튀김 여긴 일본 전국 우동집 두번째 방문 기본에 충실하다 를 몸소 실천하는 곳 오후 마감 모리야 우동 자루우동 추가 잘못 추가해서 유일하게 면 좀 남김 테우치 츠루마루 우동 카레 우동 튀김 해장을 하기에 최적 술한잔하며 먹기에도 좋음 고에몬 우동 쿠로 카레 우동 한국분들이 딱 좋아할 칼칼하고 걸죽한 느낌 우동 바카이치다이 가마버터 우동 버터향과 후추향의 만남이 색다름 아침에 먹기 딱 두번째 우동투어지만 또 갈 의사 우동투어 관심있으시면 댓글 남겨주세요 #다카마쓰 #다카마쓰여행 #일본여행 #여행에미치다 #우동투어 #먹방여행
# Sentiment: POSITIVE, Confidence: 0.6192041635513306
#
# Sentence: 다카마쓰 점심만 운영하는 진또배기 우동맛집 일본 다카마쓰 위치한 #수타우동후게츠 제가 다카마쓰에서 가본 우동 맛집 중 TOP 드는 곳으로 면발이 아주 떡처럼 탱글탱글한 맛집입니다 점심만 운영하는 곳으로 웨이팅이 살발하지만 웨이팅의 가치가 있는 곳 저희가 시킨 메뉴는 가라아게 붓카케와 자루우동 여기는 닭튀김이랑 함께 나오는 게 특징이며 바삭하고 육즙도 적당해서 좋았습니다 면빨도 역시 정말 탱글탱글 쫀득쫀득 최고 일본은 역시 냉우동이 최고입니다 기회 되시면 꼭 챙기세요 #다카마쓰 #다카마쓰맛집 #takamatsu #다카마쓰우동 #일본
# Sentiment: POSITIVE, Confidence: 0.6496217846870422
#
# Sentence: 이미 나오시마 여행을 했었다 세상은 넓고 갈 곳도 많은데 다시 찾기 쉽지 않은 세토내해 섬 여행 이번에는 딸과 함께 디자인여행이라는 거창한 타이틀을 붙이고 여행ppt도 만들었다 평소 계획형 인간이긴 하지만 섬 여행은 분 단위 계획이 필요하다 배시간 차시간 특히 미술관 예약시간을 맞춰 움직여야 한다 나오시마 여행때 뮤지엄 휴무일 체크를 했음에도 일본은 휴관일이 공휴일이면 다음날도 쉰다 놓친 전시가 있었다 이번 나오시마는 구석구석 #전기자전거 타고 맘껏 누리고 왔다 나오시마 미에노우라 항 여객선 터미널 혼무라항_SANAA 나오시마 파빌리온 _후지모토 소우 나오시마 홀 _삼부이치 히로시 #미하치나오시마 #다카마쓰여행
# Sentiment: POSITIVE, Confidence: 0.6827300786972046
#
# Sentence: 봄날 벚꽃 그리고 다카마쓰 지친 일상에서 잠시 벗어나고 싶다면 아름다운 자연이 있는 다카마쓰로 떠나보세요 운항 정보 운항 스케줄 주 운항 인천ICN 다카마쓰TAK 다카마쓰TAK 인천ICN 구매 특전 리쓰린공원 입장권쇼도지마 페리 승선권 증정 선착순 세토우치 국제예술제 패스권 증정 상당 추첨 붓쇼잔 온천패스 할인 방문객 한정 봄 추천명소 리쓰린 공원 벚꽃매화의 향연과 야간 즐겨봄 쇼도지마섬 간조에만 만날 수 있는 엔젤로드를 걸어봄 세토우치 국제예술제 현대 아트 예술과 자연의 조화로움을 느껴봄 항공권 구매하러 상단 프로필 링크 클릭하기
# Sentiment: POSITIVE, Confidence: 0.686368465423584
#
# Sentence: 아들과 #일본여행 일본 소도시 #다카마츠 비행기라 새벽 기상해 일본으로 날라오니 정신 없지만 소도시 항구의 독특한 풍경에 잠시 힐링 근데 느무 뜨거워 계속 휴식을 취해줘야 더위 먹기 딱 좋은 날씨인데 다행히 바람은 분다 어제는 였다는데 오늘은 ㅋㅋ 수시로 편의점 카페 박물관 들러 에어컨 바람 쐬는중 이곳은 소코쿠무라 박물관 오늘은 요기만 들르고 돈키오테 가서 쇼핑하고 돌고래 떠다니는 전통축제 보고 숙소로 Wakayama 다다미 숙소 아고다 평점 예약했는데 작지만 참 깨끗하고 친절하다 반나절 걸어 걸었네 남은 여행도 화이팅 여름 일본여행은 양산이 필수 #일본 #다카마츠여행 #소코쿠무라 #일본여행후기
# Sentiment: POSITIVE, Confidence: 0.6466662883758545
#
# Sentence: #다카마츠 #야마고에 #도쿠시마 #하치만야 우동의 성지 다카마츠 우동이 이런 맛이였어 개업 하치만야 쿄와 오이캇타데 타노시캇타
# Sentiment: POSITIVE, Confidence: 0.6056147217750549
#
# Sentence: #다카마츠#takamatsu
# Sentiment: POSITIVE, Confidence: 0.5441035032272339
#
# Sentence: 봄바람 살랑 마음도 살랑 역시 일본은 벚꽃 나라였어 rena_enp Ota Shimomachi Takamatsu Kagawa #일본여행 #소도시여행 #일본 #다카마츠 #오늘여기일본 #여행스타그램 #해외여행지추천 #trip#travel#travelphotography #봄내음을기록해봄 #캐논이미지스토밍
# Sentiment: POSITIVE, Confidence: 0.5478823184967041
#
# Sentence: LCC AIR SEOUL w airseouljp_official takamatsu_mint_fan_club #airseoul #takamatsuairport #다카마츠 #다카마츠공항 #다카마츠여행 #서울여행 #여행기록
# Sentiment: POSITIVE, Confidence: 0.6142351627349854
#
# Sentence: #다카마쓰여행 #우동맛집 #마쯔시타제면소
# Sentiment: POSITIVE, Confidence: 0.5713530778884888
